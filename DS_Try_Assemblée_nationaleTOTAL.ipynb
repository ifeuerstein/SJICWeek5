# %% [markdown]
# <a href="https://colab.research.google.com/github/ifeuerstein/SJICWeek5/blob/main/DS_Try_Assembl%C3%A9e_nationaleTOTAL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # An example scraper using a list
#
# The code below can be copied and adapted to create your own scraper.
#
# The first part installs all the libraries. I've kept this separate to the other parts so that you don't have to install them every time you want to run the scraper itself.

# %%
#install the libraries 
#scraperwiki is a library for scraping webpages
# !pip install scraperwiki
import scraperwiki
#lxml.html is used to convert it into xml (more structured)
import lxml.html
#cssselect is used to drill down into that and find data in tags
# !pip install cssselect
import cssselect
#the pandas library which is used to work with data - we call it 'pd' here so we have to type less!
import pandas as pd
# Out:
# Requirement already satisfied: scraperwiki in /usr/local/lib/python3.7/dist-packages (0.5.1)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from scraperwiki) (1.5.5)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from scraperwiki) (1.15.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from scraperwiki) (2.23.0)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.7/dist-packages (from scraperwiki) (1.3.23)
# Requirement already satisfied: python-editor>=0.3 in /usr/local/lib/python3.7/dist-packages (from alembic->scraperwiki) (1.0.4)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->scraperwiki) (1.1.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from alembic->scraperwiki) (2.8.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->scraperwiki) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->scraperwiki) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->scraperwiki) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->scraperwiki) (3.0.4)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->scraperwiki) (1.1.1)
# Requirement already satisfied: cssselect in /usr/local/lib/python3.7/dist-packages (1.1.0)

# %% [markdown]
# ## Using a list
#
# Below we write some code to create a list of counties that can be used to generate URLs on a karting site.
#
# We also store the 'base URL' that we will add to each item in the list to create a full URL.

# %%
#Create the basic URL that appears before the number
baseurl = "https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page="
#Create a list of numbers to put on the end
pagenums = range(1,75)
#Now generate the URLs by looping through the list and adding it to the URL
for i in pagenums:
  #Convert i to a string
  i = str(i)
  #Combine the two
  fullurl = baseurl+i
  #print it
  print(fullurl)
# Out:
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=1
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=2
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=3
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=4
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=5
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=6
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=7
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=8
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=9
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=10
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=11
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=12
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=13
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=14
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=15
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=16
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=17
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=18
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=19
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=20
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=21
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=22
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=23
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=24
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=25
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=26
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=27
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=28
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=29
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=30
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=31
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=32
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=33
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=34
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=35
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=36
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=37
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=38
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=39
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=40
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=41
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=42
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=43
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=44
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=45
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=46
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=47
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=48
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=49
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=50
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=51
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=52
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=53
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=54
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=55
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=56
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=57
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=58
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=59
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=60
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=61
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=62
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=63
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=64
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=65
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=66
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=67
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=68
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=69
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=70
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=71
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=72
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=73
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=74

# %% [markdown]
# ## Using a loop
#
# Next we loop through each item in the list and add it to that base url using the `+` operator.
#
# We add a `print` function inside the loop to check that it works each time - and copy those links into a browser to check that they are the right links.

# %% [markdown]
# ## Scraping each URL as we loop
#
# Now that we know the loop works in generating the right URLs, we can extend the code inside the loop so that it *scrapes* each URL.
#
# At this point we are using some of the libraries we imported at the start. `scraperwiki.scrape()`, for example, is the `scrape()` function from the `scraperwiki` library.
#
# Let's look at the code first, and then explain it...

# %%
#start looping through our list
for i in pagenums:
  #Convert i to a string
  i = str(i)
  #Combine the two
  fullurl = baseurl+i
  #print it
  print(fullurl)
  #Scrape the html at that url
  html = scraperwiki.scrape(fullurl)
  # turn our HTML into an lxml object
  root = lxml.html.fromstring(html) 
  #The names are all in <h2> and then <a 
  #This targets the contents of those html tags
  depute = root.cssselect('p')
  #the results are always a list so we have to loop through it using a 'for' loop
  for i in depute:
    #each item in the list is called i as it loops
    print(i)
    #on its own it looks odd, but we can attach .text_content() to translate it into text
    depute = i.text_content()
    print(depute)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df160bf0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df1606b0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df160350>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df1608f0>
# M. Ãric Coquerel
# <Element p at 0x7fe5df1602f0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160b30>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df160c50>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160830>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df160230>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec4a830>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5debf3fb0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debf3d70>
# M. Patrick Mignola
# <Element p at 0x7fe5debf3410>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debf3dd0>
# M. Marc Le Fur
# <Element p at 0x7fe5debf3e30>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debf3e90>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5debf3ef0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debf3f50>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5debf3c50>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debf3830>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5debf3d10>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfdb90>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=21
# <Element p at 0x7fe5debfd050>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debfd590>
# M. Fabrice Brun
# <Element p at 0x7fe5debfdd10>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debfdad0>
# M. Christophe Naegelen
# <Element p at 0x7fe5debfdb30>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debfdb90>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08650>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08710>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec082f0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08410>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08890>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08ef0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec083b0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08590>
# M. Fabien Di Filippo
# <Element p at 0x7fe5dec086b0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec085f0>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5dec08530>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08e90>
# M. Christophe Naegelen
# <Element p at 0x7fe5dec08350>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160590>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160a70>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5df1603b0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160b90>
# M. Paul-AndrÃ© Colombani
# <Element p at 0x7fe5df160710>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160bf0>
# M. Jean-FÃ©lix Acquaviva
# <Element p at 0x7fe5df1606b0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160350>
# M. Ãric Coquerel
# <Element p at 0x7fe5df1608f0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df1602f0>
# Mme Sabine Rubin
# <Element p at 0x7fe5df160b30>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160c50>
# Mme Sabine Rubin
# <Element p at 0x7fe5df160830>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160230>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec4a830>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debf3fb0>
# M. Ãric Coquerel
# <Element p at 0x7fe5debf3d70>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debf3410>
# Mme Sabine Rubin
# <Element p at 0x7fe5debf3dd0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3e30>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=22
# <Element p at 0x7fe5dec160b0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec16170>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec161d0>
# Article 4
# <Element p at 0x7fe5dec16110>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec165f0>
# Article 4
# <Element p at 0x7fe5dec166b0>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5dec16350>
# Article 4
# <Element p at 0x7fe5dec162f0>
# M. Fabien Roussel
# <Element p at 0x7fe5dec16470>
# Article 4
# <Element p at 0x7fe5dec164d0>
# M. Christophe Jerretie
# <Element p at 0x7fe5df167dd0>
# Article 4, alinÃ©a 3
# <Element p at 0x7fe5df167d70>
# Mme ValÃ©rie Rabault
# <Element p at 0x7fe5debfdd70>
# Article 4, alinÃ©a 11
# <Element p at 0x7fe5debfddd0>
# Mme Patricia Lemoine
# <Element p at 0x7fe5debfd830>
# Article 4, alinÃ©a 11
# <Element p at 0x7fe5debfd7d0>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5debfde90>
# Article 4
# <Element p at 0x7fe5debfdad0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debfdb30>
# Article 4, alinÃ©a 61
# <Element p at 0x7fe5debfdb90>
# M. Ãric Woerth
# <Element p at 0x7fe5dec08710>
# Article 4, alinÃ©a 64
# <Element p at 0x7fe5dec08950>
# M. Jean-RenÃ© Cazeneuve
# <Element p at 0x7fe5dec08650>
# Article 4, alinÃ©a 61
# <Element p at 0x7fe5dec082f0>
# Mme Stella Dupont
# <Element p at 0x7fe5dec084d0>
# Article 4, alinÃ©a 65
# <Element p at 0x7fe5dec08410>
# Mme Patricia Lemoine
# <Element p at 0x7fe5dec08890>
# Article 4, alinÃ©a 65
# <Element p at 0x7fe5dec08ef0>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5dec083b0>
# Article 4
# <Element p at 0x7fe5dec08590>
# M. Christophe Naegelen
# <Element p at 0x7fe5dec086b0>
# Article 4, alinÃ©a 79
# <Element p at 0x7fe5dec085f0>
# Mme Josiane Corneloup
# <Element p at 0x7fe5dec08530>
# AprÃ¨s l'Article 4
# <Element p at 0x7fe5dec08e90>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08350>
# Article 5
# <Element p at 0x7fe5df160590>
# M. Ãric Coquerel
# <Element p at 0x7fe5df160530>
# Article 5, alinÃ©a 10
# <Element p at 0x7fe5df160a70>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5df1603b0>
# Article 5, alinÃ©a 14
# <Element p at 0x7fe5df160b90>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5df160710>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5df160bf0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=23
# <Element p at 0x7fe5debf3e90>
# AprÃ¨s l'Article 5
# <Element p at 0x7fe5debf3ef0>
# M. Jacques Cattin
# <Element p at 0x7fe5debf3f50>
# AprÃ¨s l'Article 5
# <Element p at 0x7fe5debf3c50>
# M. Benoit Simian
# <Element p at 0x7fe5debf3d10>
# AprÃ¨s l'Article 5
# <Element p at 0x7fe5debf3e30>
# Mme Josiane Corneloup
# <Element p at 0x7fe5debf3fb0>
# Article 6
# <Element p at 0x7fe5debf3410>
# Mme Sabine Rubin
# <Element p at 0x7fe5debf3830>
# Article 6, alinÃ©a 4
# <Element p at 0x7fe5debf3dd0>
# Mme Josiane Corneloup
# <Element p at 0x7fe5dec16230>
# Article 6, alinÃ©a 4
# <Element p at 0x7fe5dec16170>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec16050>
# Article 6, alinÃ©a 5
# <Element p at 0x7fe5dec160b0>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5dec161d0>
# Article 7
# <Element p at 0x7fe5dec16110>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec165f0>
# Article 7, alinÃ©a 4
# <Element p at 0x7fe5dec166b0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec16350>
# Article 7, alinÃ©a 4
# <Element p at 0x7fe5dec162f0>
# Mme Cendra Motin
# <Element p at 0x7fe5dec16470>
# AprÃ¨s l'Article 7
# <Element p at 0x7fe5dec164d0>
# Mme Cendra Motin
# <Element p at 0x7fe5df167dd0>
# AprÃ¨s l'Article 7
# <Element p at 0x7fe5df167d70>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5debfdd70>
# AprÃ¨s l'Article 7
# <Element p at 0x7fe5debfddd0>
# Mme Lise Magnier
# <Element p at 0x7fe5debfd830>
# Article 8
# <Element p at 0x7fe5debfd7d0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5debfde90>
# Article 8
# <Element p at 0x7fe5debfdad0>
# M. Ãric Coquerel
# <Element p at 0x7fe5debfdb30>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5debfdb90>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08710>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5dec08950>
# M. Dino Cinieri
# <Element p at 0x7fe5dec08650>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5dec082f0>
# M. Marc Le Fur
# <Element p at 0x7fe5dec084d0>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5dec08410>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec08890>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5dec08ef0>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec083b0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec08590>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=24
# <Element p at 0x7fe5debf3c50>
# Article 8, alinÃ©a 4
# <Element p at 0x7fe5debf3d10>
# M. Jean-FÃ©lix Acquaviva
# <Element p at 0x7fe5debf3e30>
# Article 8, alinÃ©a 6
# <Element p at 0x7fe5debf3fb0>
# M. Jean-FÃ©lix Acquaviva
# <Element p at 0x7fe5debf3830>
# Article 8, alinÃ©a 6
# <Element p at 0x7fe5debf3dd0>
# M. Fabien Roussel
# <Element p at 0x7fe5dec16230>
# Article 8
# <Element p at 0x7fe5dec16170>
# M. Mohamed Laqhila
# <Element p at 0x7fe5dec16050>
# Article 8, alinÃ©a 7
# <Element p at 0x7fe5dec160b0>
# M. Patrick Hetzel
# <Element p at 0x7fe5dec161d0>
# Article 8, alinÃ©a 17
# <Element p at 0x7fe5dec16110>
# M. Ãric Woerth
# <Element p at 0x7fe5dec165f0>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5dec166b0>
# Mme ValÃ©rie Rabault
# <Element p at 0x7fe5dec16350>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5dec162f0>
# M. Marc Le Fur
# <Element p at 0x7fe5dec16470>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5dec164d0>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5df167dd0>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5df167d70>
# Mme Sabine Rubin
# <Element p at 0x7fe5debfdd70>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5debfddd0>
# M. Ãric Coquerel
# <Element p at 0x7fe5debfd830>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5debfd7d0>
# Mme Sabine Rubin
# <Element p at 0x7fe5debfde90>
# Article 8, alinÃ©a 28
# <Element p at 0x7fe5debfdad0>
# M. Marc Le Fur
# <Element p at 0x7fe5debfdb30>
# Article 8, alinÃ©a 28
# <Element p at 0x7fe5debfdb90>
# Mme ValÃ©rie Rabault
# <Element p at 0x7fe5dec086b0>
# Article 8, alinÃ©a 28
# <Element p at 0x7fe5dec085f0>
# M. Fabien Roussel
# <Element p at 0x7fe5dec08530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08e90>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08350>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08590>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08950>
# M. Bertrand Pancher
# <Element p at 0x7fe5dec08650>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec082f0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08410>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec08890>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec08ef0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=25
# <Element p at 0x7fe5df160b30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160530>
# M. Ãric Coquerel
# <Element p at 0x7fe5df1603b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160b90>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160710>
# M. Fabien Roussel
# <Element p at 0x7fe5debf3f50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3c50>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5debf3d10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3e30>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5debf3fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3830>
# Mme Sabine Rubin
# <Element p at 0x7fe5debf3dd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16230>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec16170>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16050>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5dec160b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec161d0>
# M. Daniel Labaronne
# <Element p at 0x7fe5dec16110>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec165f0>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec166b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16350>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec162f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16470>
# M. Daniel Labaronne
# <Element p at 0x7fe5dec164d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167dd0>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5df167d70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdd70>
# M. Jean-Michel Jacques
# <Element p at 0x7fe5debfddd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd830>
# M. Thomas Rudigoz
# <Element p at 0x7fe5debfd7d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfde90>
# M. Daniel Labaronne
# <Element p at 0x7fe5debfdad0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdb30>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5debfdb90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec083b0>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec086b0>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5dec085f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08530>
# M. StÃ©phane Peu
# <Element p at 0x7fe5dec08e90>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec08350>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=26
# <Element p at 0x7fe5dec5aef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec4a7d0>
# M. AurÃ©lien TachÃ©
# <Element p at 0x7fe5dec4a5f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec4a770>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5dec4a710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec44ef0>
# M. Jean-Luc Lagleize
# <Element p at 0x7fe5dec28950>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1608f0>
# M. Fabrice Brun
# <Element p at 0x7fe5df160770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160470>
# M. Patrick Hetzel
# <Element p at 0x7fe5df160710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3c50>
# M. Patrice Anato
# <Element p at 0x7fe5debf3f50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3d10>
# Mme Lise Magnier
# <Element p at 0x7fe5debf3e30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3fb0>
# M. Robin Reda
# <Element p at 0x7fe5debf3830>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3dd0>
# M. Mohamed Laqhila
# <Element p at 0x7fe5dec16230>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16170>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec16050>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec160b0>
# M. Marc Le Fur
# <Element p at 0x7fe5dec161d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16110>
# M. Dino Cinieri
# <Element p at 0x7fe5dec165f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec166b0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec16350>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec162f0>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec16470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec164d0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df167470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167350>
# M. Daniel Labaronne
# <Element p at 0x7fe5df167410>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167710>
# Mme Sabine Rubin
# <Element p at 0x7fe5df1675f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167dd0>
# M. Patrick Hetzel
# <Element p at 0x7fe5df167d70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd2f0>
# M. Patrice Anato
# <Element p at 0x7fe5debfda70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdd70>
# Mme Lise Magnier
# <Element p at 0x7fe5debfddd0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfd830>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=27
# <Element p at 0x7fe5dec083b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08710>
# M. Robin Reda
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08650>
# M. Fabrice Brun
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08410>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08890>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec082f0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec086b0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec085f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08530>
# M. Patrick Hetzel
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5afb0>
# M. Patrice Anato
# <Element p at 0x7fe5dec5aa70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5aef0>
# Mme Lise Magnier
# <Element p at 0x7fe5dec4a7d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec4a5f0>
# M. Vincent Rolland
# <Element p at 0x7fe5dec4a770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec4a710>
# M. Robin Reda
# <Element p at 0x7fe5dec44ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec28950>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5df1608f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160770>
# M. Charles de Courson
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160710>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debf3c50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3f50>
# Mme Lise Magnier
# <Element p at 0x7fe5debf3d10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3e30>
# M. Dino Cinieri
# <Element p at 0x7fe5debf3fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3830>
# M. Marc Le Fur
# <Element p at 0x7fe5debf3dd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16230>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec16170>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16050>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec160b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec161d0>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec16110>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec165f0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec166b0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec16350>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=28
# <Element p at 0x7fe5df1675f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167dd0>
# M. Marc Le Fur
# <Element p at 0x7fe5df167d70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdad0>
# M. FranÃ§ois Jolivet
# <Element p at 0x7fe5debfde90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdb30>
# M. Charles de Courson
# <Element p at 0x7fe5debfdb90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd830>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5debfd2f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfda70>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5debfdd70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfddd0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debfd7d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08590>
# M. Fabrice Brun
# <Element p at 0x7fe5dec083b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08350>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec08710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08950>
# Mme ValÃ©rie Bazin-Malgras
# <Element p at 0x7fe5dec08650>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec084d0>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08410>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08890>
# M. Fabrice Brun
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08ef0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec086b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec085f0>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5dec08530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08e90>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5dec5afb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5aa70>
# Mme Brigitte Kuster
# <Element p at 0x7fe5dec5aef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec4a7d0>
# M. Fabien Di Filippo
# <Element p at 0x7fe5dec4a5f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec4a770>
# M. Ãric Woerth
# <Element p at 0x7fe5dec4a710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec44ef0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec28950>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1608f0>
# M. Arnaud Viala
# <Element p at 0x7fe5df160770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160470>
# M. Charles de Courson
# <Element p at 0x7fe5df160710>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3c50>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=29
# <Element p at 0x7fe5dec165f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec166b0>
# M. Bertrand Pancher
# <Element p at 0x7fe5debf3c50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3d10>
# M. Dino Cinieri
# <Element p at 0x7fe5debf3f50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3e30>
# M. Fabrice Brun
# <Element p at 0x7fe5debf3fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3830>
# M. Ãric Woerth
# <Element p at 0x7fe5debf3dd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167350>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5df167410>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1675f0>
# Mme Lise Magnier
# <Element p at 0x7fe5df167dd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167d70>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5debfdad0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfde90>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debfdb30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdb90>
# M. Vincent Descoeur
# <Element p at 0x7fe5debfd830>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd2f0>
# Mme Sylvia Pinel
# <Element p at 0x7fe5debfda70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdd70>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5debfddd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd7d0>
# M. Arnaud Viala
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec083b0>
# M. Julien Aubert
# <Element p at 0x7fe5dec08350>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08710>
# Mme Emmanuelle Anthoine
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08650>
# Mme ValÃ©rie Bazin-Malgras
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08410>
# Mme Ãmilie Bonnivard
# <Element p at 0x7fe5dec08890>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec082f0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec086b0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec085f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08530>
# Mme Jeanine DubiÃ©
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5afb0>
# Mme Lise Magnier
# <Element p at 0x7fe5dec5aa70>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec5aef0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=30
# <Element p at 0x7fe5df1aed70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1aed10>
# Mme Danielle Brulebois
# <Element p at 0x7fe5df165bf0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1616b0>
# M. Dino Cinieri
# <Element p at 0x7fe5debdbad0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df13e770>
# M. Jacques Cattin
# <Element p at 0x7fe5dec10ad0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160470>
# M. Benoit Simian
# <Element p at 0x7fe5dec44ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec160b0>
# M. Bertrand Pancher
# <Element p at 0x7fe5dec16f50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec165f0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec16110>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec166b0>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5debf3b90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3bf0>
# M. Marc Le Fur
# <Element p at 0x7fe5debf3c50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3d10>
# M. Laurent Saint-Martin
# <Element p at 0x7fe5debf3f50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3e30>
# Mme Sabine Rubin
# <Element p at 0x7fe5debf3fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3830>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5debf3dd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167350>
# M. Charles de Courson
# <Element p at 0x7fe5df167410>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1675f0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df167dd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167d70>
# M. Mohamed Laqhila
# <Element p at 0x7fe5debfdad0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfde90>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5debfdb30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdb90>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5debfd830>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd2f0>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5debfda70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdd70>
# M. Mohamed Laqhila
# <Element p at 0x7fe5debfddd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd7d0>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec083b0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec08350>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec08710>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=31
# <Element p at 0x7fe5dec5aa70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5a770>
# M. Dino Cinieri
# <Element p at 0x7fe5dec5acb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5ab30>
# M. Dino Cinieri
# <Element p at 0x7fe5dec5a9b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5ac50>
# M. Dino Cinieri
# <Element p at 0x7fe5dec5aef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5afb0>
# M. Dino Cinieri
# <Element p at 0x7fe5df1aed70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1ae6b0>
# M. Dino Cinieri
# <Element p at 0x7fe5df1aed10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df165bf0>
# M. Marc Le Fur
# <Element p at 0x7fe5df1616b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debdbad0>
# M. Marc Le Fur
# <Element p at 0x7fe5df13e770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10ad0>
# M. Dino Cinieri
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec44ef0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec160b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16f50>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec165f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec16110>
# M. Dino Cinieri
# <Element p at 0x7fe5dec166b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3b90>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debf3bf0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3c50>
# M. Julien Dive
# <Element p at 0x7fe5debf3d10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3f50>
# M. Dino Cinieri
# <Element p at 0x7fe5debf3e30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3fb0>
# M. Dino Cinieri
# <Element p at 0x7fe5debf3830>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3dd0>
# M. Marc Le Fur
# <Element p at 0x7fe5df167350>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167410>
# M. Marc Le Fur
# <Element p at 0x7fe5df1675f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167dd0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df167d70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdad0>
# Mme Emmanuelle Anthoine
# <Element p at 0x7fe5debfde90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdb30>
# Mme ValÃ©rie Bazin-Malgras
# <Element p at 0x7fe5debfdb90>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfd830>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=32
# <Element p at 0x7fe5dec08890>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08950>
# Mme Ãmilie Bonnivard
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08650>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08410>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec082f0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec086b0>
# M. Charles de Courson
# <Element p at 0x7fe5dec08530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08e90>
# Mme Josiane Corneloup
# <Element p at 0x7fe5dec08710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08590>
# M. Julien Aubert
# <Element p at 0x7fe5dec083b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08350>
# M. Jacques Cattin
# <Element p at 0x7fe5dec5a8f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5aa70>
# M. Arnaud Viala
# <Element p at 0x7fe5dec5a770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5acb0>
# M. Benoit Simian
# <Element p at 0x7fe5dec5ab30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5a9b0>
# M. Marc Le Fur
# <Element p at 0x7fe5dec5ac50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5aef0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec5afb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1aed70>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df1ae6b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1aed10>
# M. Charles de Courson
# <Element p at 0x7fe5df165bf0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1616b0>
# M. Fabien Roussel
# <Element p at 0x7fe5debdbad0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df13e770>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5dec10ad0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160470>
# M. Bertrand Pancher
# <Element p at 0x7fe5dec44ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec160b0>
# Mme Patricia Lemoine
# <Element p at 0x7fe5dec16f50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec165f0>
# Mme Patricia Lemoine
# <Element p at 0x7fe5dec16110>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec166b0>
# M. Vincent Ledoux
# <Element p at 0x7fe5debf3b90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3bf0>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5debf3c50>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3d10>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=33
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08410>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08ef0>
# Mme Lise Magnier
# <Element p at 0x7fe5dec086b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08530>
# Mme Sylvia Pinel
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08710>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec083b0>
# Mme FrÃ©dÃ©rique Lardet
# <Element p at 0x7fe5dec08350>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5a8f0>
# Mme Lise Magnier
# <Element p at 0x7fe5dec5aa70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5a770>
# Mme FrÃ©dÃ©rique Lardet
# <Element p at 0x7fe5dec5acb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5ab30>
# Mme Sylvia Pinel
# <Element p at 0x7fe5dec5a9b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5ac50>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec5aef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5afb0>
# Mme GeneviÃ¨ve Levy
# <Element p at 0x7fe5df1aed70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1ae6b0>
# M. Ãric Coquerel
# <Element p at 0x7fe5df1aed10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df165bf0>
# Mme Lise Magnier
# <Element p at 0x7fe5df1616b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debdbad0>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5df13e770>
# Article 9
# <Element p at 0x7fe5dec10ad0>
# M. Christophe Naegelen
# <Element p at 0x7fe5df160470>
# Article 9, alinÃ©a 38
# <Element p at 0x7fe5dec44ef0>
# M. FranÃ§ois Ruffin
# <Element p at 0x7fe5dec160b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec16f50>
# M. Fabrice Brun
# <Element p at 0x7fe5dec165f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec16110>
# M. Marc Le Fur
# <Element p at 0x7fe5dec166b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3e30>
# M. Dino Cinieri
# <Element p at 0x7fe5debf3f50>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3fb0>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5debf3830>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3dd0>
# M. Vincent Descoeur
# <Element p at 0x7fe5debf3d10>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3b90>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=34
# <Element p at 0x7fe5debfdb30>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08950>
# Mme Sylvia Pinel
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08410>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08ef0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec086b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08530>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08710>
# M. StÃ©phane Peu
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec083b0>
# M. AurÃ©lien TachÃ©
# <Element p at 0x7fe5dec08350>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5a8f0>
# Mme Josiane Corneloup
# <Element p at 0x7fe5dec5aa70>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5a770>
# M. Patrick Hetzel
# <Element p at 0x7fe5dec5acb0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5ab30>
# M. Patrice Anato
# <Element p at 0x7fe5dec5a9b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5ac50>
# M. Vincent Rolland
# <Element p at 0x7fe5dec5aef0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5afb0>
# Mme Lise Magnier
# <Element p at 0x7fe5df1aed70>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df1ae6b0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df1aed10>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df165bf0>
# M. Robin Reda
# <Element p at 0x7fe5df1616b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debdbad0>
# Mme Brigitte Kuster
# <Element p at 0x7fe5df13e770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec10ad0>
# M. Fabrice Brun
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec44ef0>
# M. Guillaume Chiche
# <Element p at 0x7fe5dec160b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec16f50>
# M. Xavier Paluszkiewicz
# <Element p at 0x7fe5dec165f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec16110>
# Mme Aina Kuric
# <Element p at 0x7fe5dec166b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3bf0>
# M. Julien Aubert
# <Element p at 0x7fe5debf3c50>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3b90>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5debf3e30>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3f50>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=35
# <Element p at 0x7fe5debfd9b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debfdbf0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec7f9b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08fb0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08f50>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08e90>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec084d0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08410>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec082f0>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec086b0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08530>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08710>
# M. Dino Cinieri
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec083b0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08350>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5a8f0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec5aa70>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5a770>
# M. Fabrice Brun
# <Element p at 0x7fe5dec5acb0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5ab30>
# M. Fabrice Brun
# <Element p at 0x7fe5dec5a9b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5ac50>
# M. Matthieu Orphelin
# <Element p at 0x7fe5dec5aef0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5afb0>
# M. Pierre-Yves Bournazel
# <Element p at 0x7fe5df1aed70>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df1ae6b0>
# M. Fabrice Brun
# <Element p at 0x7fe5df1aed10>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df165bf0>
# M. Matthieu Orphelin
# <Element p at 0x7fe5df1616b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debdbad0>
# M. Julien Aubert
# <Element p at 0x7fe5df13e770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec10ad0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df1600b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160650>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5df160a10>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160470>
# M. Pascal Brindeau
# <Element p at 0x7fe5dec44ef0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec167d0>
# M. Vincent Rolland
# <Element p at 0x7fe5dec160b0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec16f50>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=36
# <Element p at 0x7fe5debf3fb0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3770>
# M. Marc Le Fur
# <Element p at 0x7fe5debf3890>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3230>
# M. Fabrice Brun
# <Element p at 0x7fe5debf3a70>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3a10>
# Mme Ãmilie Bonnivard
# <Element p at 0x7fe5debf3950>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf37d0>
# M. Denis MassÃ©glia
# <Element p at 0x7fe5debf3830>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3dd0>
# M. Marc Le Fur
# <Element p at 0x7fe5debf3d10>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3f50>
# Mme Sabine Rubin
# <Element p at 0x7fe5debf3bf0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3c50>
# M. Jean-Marc Zulesi, rapporteur de la commission du dÃ©veloppement durable et de l'amÃ©nagement du territoire
# <Element p at 0x7fe5debf3b90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3e30>
# M. Fabien Roussel
# <Element p at 0x7fe5debfd9b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debfdb90>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5debfdbf0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec7f9b0>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5dec08fb0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08f50>
# M. Matthieu Orphelin
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08950>
# M. Michel Castellani
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08410>
# M. Jean-Marc Zulesi, rapporteur de la commission du dÃ©veloppement durable et de l'amÃ©nagement du territoire
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08ef0>
# Mme Laurianne Rossi
# <Element p at 0x7fe5dec086b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08530>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08710>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08590>
# M. Fabrice Brun
# <Element p at 0x7fe5dec083b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08350>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec5a8f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5aa70>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5dec5a770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5acb0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec5ab30>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5a9b0>
# Mme Ãmilie Bonnivard
# <Element p at 0x7fe5dec5ac50>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec5aef0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=37
# <Element p at 0x7fe5df13e770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df1600b0>
# M. Fabien Di Filippo
# <Element p at 0x7fe5df160650>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160a10>
# M. Julien Dive
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec44ef0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec160b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec165f0>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5dec16110>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec166b0>
# Mme Ãmilie Bonnivard
# ...
# <Element p at 0x7fe5dec10770>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10650>
# M. Charles de Courson
# <Element p at 0x7fe5dec10bf0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdbad0>
# Mme ValÃ©rie Bazin-Malgras
# <Element p at 0x7fe5debdbdd0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdb470>
# Mme Emmanuelle Anthoine
# <Element p at 0x7fe5debdb230>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdb4d0>
# M. StÃ©phane TestÃ©
# <Element p at 0x7fe5debdb530>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdb410>
# Mme Monica Michel
# <Element p at 0x7fe5debdb170>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec859b0>
# Mme Marie Tamarelle-Verhaeghe
# <Element p at 0x7fe5dec85950>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5df1aed70>
# M. Jean-Michel Jacques
# <Element p at 0x7fe5df1ae6b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5ac50>
# M. Gabriel Serville
# <Element p at 0x7fe5dec5afb0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5aa70>
# Mme SÃ©verine Gipson
# <Element p at 0x7fe5dec5a8f0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a770>
# Mme Danielle Brulebois
# <Element p at 0x7fe5dec5acb0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a9b0>
# M. Patrick Vignal
# <Element p at 0x7fe5dec5aef0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a710>
# M. Patrice Anato
# <Element p at 0x7fe5dec5a7d0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5add0>
# M. Olivier Becht
# <Element p at 0x7fe5debf3bf0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3770>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=70
# <Element p at 0x7fe5dec4a830>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5df1616b0>
# Mme Isabelle Valentin
# <Element p at 0x7fe5df1600b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5df160bf0>
# M. RÃ©mi Delatte
# <Element p at 0x7fe5debfdf50>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfd590>
# M. StÃ©phane Viry
# <Element p at 0x7fe5debfd050>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfdd10>
# M. Christophe Naegelen
# <Element p at 0x7fe5dec10c50>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec101d0>
# M. Bertrand Bouyx
# <Element p at 0x7fe5dec10710>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10b30>
# Mme FrÃ©dÃ©rique Tuffnell
# <Element p at 0x7fe5dec105f0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10e90>
# Mme Aude Bono-Vandorme
# <Element p at 0x7fe5dec10770>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10650>
# M. Jean-Hugues Ratenon
# <Element p at 0x7fe5dec10bf0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdbad0>
# M. Thierry Michels
# <Element p at 0x7fe5debdbdd0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdb470>
# M. Vincent Rolland
# <Element p at 0x7fe5debdb230>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdb4d0>
# M. Emmanuel Maquet
# <Element p at 0x7fe5debdb530>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdb410>
# M. Robin Reda
# <Element p at 0x7fe5debdb170>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec859b0>
# Mme Stella Dupont
# <Element p at 0x7fe5dec85950>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5df1aed70>
# M. Jean-Yves Bony
# <Element p at 0x7fe5df1ae6b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5ac50>
# M. FranÃ§ois Jolivet
# <Element p at 0x7fe5dec5afb0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5aa70>
# Mme Huguette Tiegna
# <Element p at 0x7fe5dec5a8f0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a770>
# M. Philippe Meyer
# <Element p at 0x7fe5dec5acb0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a9b0>
# Mme FranÃ§oise Dumas
# <Element p at 0x7fe5dec5aef0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a710>
# M. Julien Aubert
# <Element p at 0x7fe5dec5a7d0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5add0>
# M. Denis Sommer
# <Element p at 0x7fe5debf3410>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3b30>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=71
# <Element p at 0x7fe5debfd590>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfd050>
# Mme Sabine Thillaye
# <Element p at 0x7fe5dec10c50>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec101d0>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5dec10710>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10b30>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5dec105f0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10e90>
# M. Patrick Mignola
# <Element p at 0x7fe5dec10770>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10650>
# Mme ValÃ©rie Rabault
# <Element p at 0x7fe5dec10bf0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdbad0>
# M. Jean-Pierre Door
# <Element p at 0x7fe5debdbdd0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdb470>
# M. Florent BoudiÃ©
# <Element p at 0x7fe5debdb230>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdb4d0>
# Mme Annie Chapelier
# <Element p at 0x7fe5debdb530>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debdb410>
# M. Arnaud Viala
# <Element p at 0x7fe5debdb170>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec859b0>
# M. Vincent Descoeur
# <Element p at 0x7fe5dec85950>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5df1aed70>
# M. Christophe Blanchet
# <Element p at 0x7fe5df1ae6b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5ac50>
# M. Jean-Pierre Cubertafon
# <Element p at 0x7fe5dec5afb0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5aa70>
# Mme Aude Luquet
# <Element p at 0x7fe5dec5a8f0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a770>
# M. Arnaud Viala
# <Element p at 0x7fe5dec5acb0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a9b0>
# Mme Anne-Laure Cattelot
# <Element p at 0x7fe5dec5aef0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a710>
# M. Xavier Roseren
# <Element p at 0x7fe5dec5a7d0>
# Article 24, alinÃ©a 25
# <Element p at 0x7fe5dec5add0>
# M. Ãric Woerth
# <Element p at 0x7fe5debf3d10>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debf3230>
# M. Bertrand Pancher
# <Element p at 0x7fe5debf3b90>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debf3a10>
# M. Bertrand Pancher
# <Element p at 0x7fe5debf37d0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debf3dd0>
# M. Jean-Paul Lecoq
# <Element p at 0x7fe5debf3950>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3c50>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=72
# <Element p at 0x7fe5dec10e90>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10650>
# M. Bertrand Pancher
# <Element p at 0x7fe5dec10bf0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debdbad0>
# M. Bertrand Pancher
# <Element p at 0x7fe5debdbdd0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debdb470>
# Mme Jennifer De Temmerman
# <Element p at 0x7fe5debdb230>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debdb4d0>
# M. Hubert Julien-LaferriÃ¨re
# <Element p at 0x7fe5debdb530>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debdb410>
# M. Fabrice Brun
# <Element p at 0x7fe5debdb170>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec859b0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec85950>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5df1aed70>
# M. Fabrice Brun
# <Element p at 0x7fe5df1ae6b0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec5ac50>
# Mme Jennifer De Temmerman
# <Element p at 0x7fe5dec5afb0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec5aa70>
# Mme Jennifer De Temmerman
# <Element p at 0x7fe5dec5a8f0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec5a770>
# Mme Jennifer De Temmerman
# <Element p at 0x7fe5dec5acb0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec5a9b0>
# Mme Anne-Laure Cattelot
# <Element p at 0x7fe5dec5aef0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec5a710>
# M. Xavier Roseren
# <Element p at 0x7fe5dec5a7d0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec5add0>
# M. Jean-Paul Lecoq
# <Element p at 0x7fe5debf3e30>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debf3f50>
# M. Hubert Julien-LaferriÃ¨re
# <Element p at 0x7fe5debf3e90>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debf3ad0>
# M. Hubert Julien-LaferriÃ¨re
# <Element p at 0x7fe5debf3a70>
# Article 24, alinÃ©a 56
# <Element p at 0x7fe5debf3ef0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debf3fb0>
# Article 24
# <Element p at 0x7fe5debf39b0>
# M. Charles de Courson
# <Element p at 0x7fe5debf3770>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debf3bf0>
# M. Michel Lauzzana
# <Element p at 0x7fe5debf3b30>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debf3410>
# M. Fabrice Brun
# <Element p at 0x7fe5debf3830>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debf38f0>
# M. Fabrice Brun
# <Element p at 0x7fe5debf3c50>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3d10>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=73
# <Element p at 0x7fe5dec44ef0>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5dec165f0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec16110>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5dec166b0>
# Mme Anne-Laure Cattelot
# <Element p at 0x7fe5dec16f50>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5dec167d0>
# Mme Anne-Laure Cattelot
# <Element p at 0x7fe5dec16470>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5dec164d0>
# M. Xavier Roseren
# <Element p at 0x7fe5df160650>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5df160a10>
# M. Xavier Roseren
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5df160350>
# M. Philippe HuppÃ©
# <Element p at 0x7fe5df1603b0>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5df160b90>
# M. Denis MassÃ©glia
# <Element p at 0x7fe5df160c50>
# Article 25
# <Element p at 0x7fe5debdb530>
# M. Ãric Coquerel
# <Element p at 0x7fe5debdbad0>
# Article 25
# <Element p at 0x7fe5debdbdd0>
# M. Ãric Woerth
# <Element p at 0x7fe5debdb470>
# Article 27
# <Element p at 0x7fe5debdb230>
# Mme Sabine Rubin
# <Element p at 0x7fe5debdb4d0>
# Article 27, alinÃ©a 2
# <Element p at 0x7fe5debdb410>
# Mme FrÃ©dÃ©rique Dumas
# <Element p at 0x7fe5debdb170>
# Article 28
# <Element p at 0x7fe5dec859b0>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec85950>
# AprÃ¨s l'Article 28
# <Element p at 0x7fe5df1aed70>
# M. Michel Zumkeller
# <Element p at 0x7fe5df1ae6b0>
# Article 30
# <Element p at 0x7fe5dec5ac50>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec5afb0>
# AprÃ¨s l'Article 30
# <Element p at 0x7fe5dec5aa70>
# M. SÃ©bastien Nadot
# <Element p at 0x7fe5dec5a8f0>
# AprÃ¨s l'Article 30
# <Element p at 0x7fe5dec5a770>
# M. Patrice Anato
# <Element p at 0x7fe5dec5acb0>
# AprÃ¨s l'Article 30
# <Element p at 0x7fe5dec5a9b0>
# M. Philippe HuppÃ©
# <Element p at 0x7fe5dec5aef0>
# Article 31
# <Element p at 0x7fe5dec5a710>
# M. Michel Zumkeller
# <Element p at 0x7fe5dec5a7d0>
# Article 31
# <Element p at 0x7fe5dec5add0>
# M. Julien Aubert
# <Element p at 0x7fe5debf3890>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debf3d70>
# M. RaphaÃ«l GÃ©rard
# <Element p at 0x7fe5debf3230>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3b90>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=74
# <Element p at 0x7fe5dec44ef0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec164d0>
# Mme Lise Magnier
# <Element p at 0x7fe5dec165f0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec16110>
# M. Charles de Courson
# <Element p at 0x7fe5dec166b0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec16f50>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5dec167d0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec16470>
# M. Mohamed Laqhila
# <Element p at 0x7fe5df160650>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5df160a10>
# Mme Sabine Rubin
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5df160350>
# Mme Marie-Pierre Rixain
# <Element p at 0x7fe5df1603b0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5df160b90>
# M. Florent BoudiÃ©
# <Element p at 0x7fe5df160c50>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debdb530>
# Mme Lise Magnier
# <Element p at 0x7fe5debdbad0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debdbdd0>
# M. Mohamed Laqhila
# <Element p at 0x7fe5debdb470>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debdb230>
# Mme Lise Magnier
# <Element p at 0x7fe5debdb4d0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debdb410>
# M. Fabien Di Filippo
# <Element p at 0x7fe5debdb170>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec859b0>
# M. Julien Aubert
# <Element p at 0x7fe5dec85950>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5df1aed70>
# M. Julien Aubert
# <Element p at 0x7fe5df1ae6b0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec5ac50>
# M. Jean-Philippe Nilor
# <Element p at 0x7fe5dec5afb0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec5aa70>
# M. Jean-Philippe Nilor
# <Element p at 0x7fe5dec5a8f0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec5a770>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits

# %% [markdown]
# ## The functions we are using
#
# Let's break some of this down.
#
# So `scraperwiki.scrape()` is the `scrape()` function from the `scraperwiki` library. The *ingredient* we give to that function is the URL we stored in the `fullurl` variable.
#
# The `scrape()` function basically fetches the whole webpage at a given address (the ingredient it's given).
#
# The results of running that function are stored in a new variable called `html`.
#
# This isn't in a form we can easily work with, yet, so we need another function to convert it to something we can drill down into.
#
# That function is the `fromstring()` function from the `lxml.html` library. The *ingredient* we give to that function is the `html` variable we just created.
#
# The results are stored in another new variable, `root`.
#
# This variable is a particular type of object (an "lxml object" if you need to know) that can be drilled down into using the `cssselect` function. That function will grab elements that match the *CSS selectors* that you give it as an ingredient.
#
# In this case we specify `'h2'`, which means "any h2 tag" - so it will grab the contents of any h2 tags in the page.
#
# Don't worry about memorising any of the code above: this is code that you can re-use time and time again. The only bit you will need to change is the selector, in order to specify the particular HTML you're after.
#
# To work out the selector you need, you'll often need to Google around, learning as you go, but selectors are pretty easy to get the hang of, and I'll talk about it more below.

# %% [markdown]
# ## Using CSS selectors
#
# **CSS selectors** are used to target different elements in a HTML page. A basic selector can target just one type of HTML tag, like `<h2>` or `<p>`, but you can also target a combination of tags (such as any `<strong>` tags within `<p>` tags).
#
# More complicated selectors can also be used to target tags based on their attributes (e.g. not just `<p>` but specifically `<p class="summary">`).
#
# You can find lots of resources to help you with CSS selectors, such as [this one](https://www.w3schools.com/cssref/css_selectors.asp). Many will relate to styling webpages (which is how CSS selectors are most often used - selectors are used to target the HTML elements that you want to style), but the principles are the same.

# %% [markdown]
# ## Saving the information we've grabbed.
#
# Now we've grabbed some information we can extend the code further to save it.
#
# At this point we need to use functions from another library: `pandas`. This is a library for data storage and analysis. When we imported `pandas` we called it `pd` for short. This is quite common. Any reference to `pd` in the code, then, means `pandas`
#
# First, we use the function `DataFrame()` which creates a pandas dataframe. As ingredients it needs to know the names of any columns.
#
# You will see below that we add a line *before* the loop which uses that to create an empty dataframe to store the data in.
#
# Then, inside the loop, the data we extract is added to the dataframe.
#
# Here's the code first - then I'll explain the new bits after.

# %%
#Create a dataframe to store the data we are about to scrape
#It has one column called 'title'
#We call this dataframe 'df'
df = pd.DataFrame(columns=["Nom"])

#start looping through our list
for i in pagenums:
  #Convert i to a string
  i = str(i)
  #Combine the two
  fullurl = baseurl+i
  #print it
  print(fullurl)
  #Scrape the html at that url
  html = scraperwiki.scrape(fullurl)
  # turn our HTML into an lxml object
  root = lxml.html.fromstring(html) 
  #There are 100 recordings on the page
  #The titles are all in <div class="title"> and then <a 
  #This targets the contents of those html tags
  depute = root.cssselect('p')
  #the results are always a list so we have to loop through it using a 'for' loop
  for i in depute:
    #each item in the list is called i as it loops
    print(i)
    #on its own it looks odd, but we can attach .text_content() to translate it into text
    depute = i.text_content()
    print(depute)
    #Now we need to store it in that variable called 'df' 
    df = df.append({
      "Nom" : depute
      }, ignore_index=True)
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec10a70>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec107d0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec10ad0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec104d0>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec10590>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec10950>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec08890>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec085f0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec08a70>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08e30>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08590>
# M. Patrick Mignola
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08410>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08f50>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08530>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec083b0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec08710>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08fb0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec08950>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec084d0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=21
# <Element p at 0x7fe5dec4a7d0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df1aed10>
# M. Fabrice Brun
# <Element p at 0x7fe5df1aed70>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df1ae6b0>
# M. Christophe Naegelen
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df1602f0>
# M. Fabrice Brun
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160230>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df160b30>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160590>
# M. Fabrice Brun
# <Element p at 0x7fe5df160830>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df160770>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df167350>
# M. Fabrice Brun
# <Element p at 0x7fe5df167e30>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df167fb0>
# M. Fabien Di Filippo
# <Element p at 0x7fe5df167cb0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df167710>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5df1675f0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df167650>
# M. Christophe Naegelen
# <Element p at 0x7fe5df167050>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df167f50>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5debfdd70>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debfd7d0>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5debfd830>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debfddd0>
# M. Paul-AndrÃ© Colombani
# <Element p at 0x7fe5debfd8f0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debfd470>
# M. Jean-FÃ©lix Acquaviva
# <Element p at 0x7fe5dec44ef0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5df165bf0>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec16170>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec160b0>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec166b0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debf3c50>
# Mme Sabine Rubin
# <Element p at 0x7fe5debf3230>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5debf38f0>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec10830>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec10fb0>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec10f50>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec10b90>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec10cb0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec108f0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=22
# <Element p at 0x7fe5dec4a7d0>
# AprÃ¨s l'Article 3
# <Element p at 0x7fe5dec08e30>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec08590>
# Article 4
# <Element p at 0x7fe5dec084d0>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec08890>
# Article 4
# <Element p at 0x7fe5dec08f50>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5dec08410>
# Article 4
# <Element p at 0x7fe5dec08e90>
# M. Fabien Roussel
# <Element p at 0x7fe5dec08a70>
# Article 4
# <Element p at 0x7fe5dec08710>
# M. Christophe Jerretie
# <Element p at 0x7fe5dec08950>
# Article 4, alinÃ©a 3
# <Element p at 0x7fe5dec08fb0>
# Mme ValÃ©rie Rabault
# <Element p at 0x7fe5dec08530>
# Article 4, alinÃ©a 11
# <Element p at 0x7fe5dec082f0>
# Mme Patricia Lemoine
# <Element p at 0x7fe5dec085f0>
# Article 4, alinÃ©a 11
# <Element p at 0x7fe5dec083b0>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5df1aed10>
# Article 4
# <Element p at 0x7fe5df1aed70>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df1ae6b0>
# Article 4, alinÃ©a 61
# <Element p at 0x7fe5df160a70>
# M. Ãric Woerth
# <Element p at 0x7fe5df1602f0>
# Article 4, alinÃ©a 64
# <Element p at 0x7fe5df160470>
# M. Jean-RenÃ© Cazeneuve
# <Element p at 0x7fe5df160230>
# Article 4, alinÃ©a 61
# <Element p at 0x7fe5df160b30>
# Mme Stella Dupont
# <Element p at 0x7fe5df160590>
# Article 4, alinÃ©a 65
# <Element p at 0x7fe5df160830>
# Mme Patricia Lemoine
# <Element p at 0x7fe5df160770>
# Article 4, alinÃ©a 65
# <Element p at 0x7fe5df160530>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5df167350>
# Article 4
# <Element p at 0x7fe5df167e30>
# M. Christophe Naegelen
# <Element p at 0x7fe5df167fb0>
# Article 4, alinÃ©a 79
# <Element p at 0x7fe5df167cb0>
# Mme Josiane Corneloup
# <Element p at 0x7fe5df167710>
# AprÃ¨s l'Article 4
# <Element p at 0x7fe5df1675f0>
# M. Marc Le Fur
# <Element p at 0x7fe5df167650>
# Article 5
# <Element p at 0x7fe5df167050>
# M. Ãric Coquerel
# <Element p at 0x7fe5df167f50>
# Article 5, alinÃ©a 10
# <Element p at 0x7fe5debfdd70>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5debfd7d0>
# Article 5, alinÃ©a 14
# <Element p at 0x7fe5debfd830>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5debfddd0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfd8f0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=23
# <Element p at 0x7fe5debf3230>
# AprÃ¨s l'Article 5
# <Element p at 0x7fe5dec08ef0>
# M. Jacques Cattin
# <Element p at 0x7fe5dec08e30>
# AprÃ¨s l'Article 5
# <Element p at 0x7fe5dec08590>
# M. Benoit Simian
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 5
# <Element p at 0x7fe5dec08890>
# Mme Josiane Corneloup
# <Element p at 0x7fe5dec08f50>
# Article 6
# <Element p at 0x7fe5dec08410>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec08e90>
# Article 6, alinÃ©a 4
# <Element p at 0x7fe5dec08a70>
# Mme Josiane Corneloup
# <Element p at 0x7fe5dec08710>
# Article 6, alinÃ©a 4
# <Element p at 0x7fe5dec08950>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec08fb0>
# Article 6, alinÃ©a 5
# <Element p at 0x7fe5dec08530>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5dec082f0>
# Article 7
# <Element p at 0x7fe5dec085f0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec083b0>
# Article 7, alinÃ©a 4
# <Element p at 0x7fe5df1aed10>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df1aed70>
# Article 7, alinÃ©a 4
# <Element p at 0x7fe5df1ae6b0>
# Mme Cendra Motin
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 7
# <Element p at 0x7fe5df1602f0>
# Mme Cendra Motin
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 7
# <Element p at 0x7fe5df160230>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df160b30>
# AprÃ¨s l'Article 7
# <Element p at 0x7fe5df160590>
# Mme Lise Magnier
# <Element p at 0x7fe5df160830>
# Article 8
# <Element p at 0x7fe5df160770>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df160530>
# Article 8
# <Element p at 0x7fe5df167350>
# M. Ãric Coquerel
# <Element p at 0x7fe5df167e30>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5df167fb0>
# M. Marc Le Fur
# <Element p at 0x7fe5df167cb0>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5df167710>
# M. Dino Cinieri
# <Element p at 0x7fe5df1675f0>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5df167650>
# M. Marc Le Fur
# <Element p at 0x7fe5df167050>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5df167f50>
# M. Ãric Coquerel
# <Element p at 0x7fe5debfd470>
# Article 8, alinÃ©a 1
# <Element p at 0x7fe5debfd8f0>
# Mme Sabine Rubin
# <Element p at 0x7fe5debfdd70>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfd7d0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=24
# <Element p at 0x7fe5dec107d0>
# Article 8, alinÃ©a 4
# <Element p at 0x7fe5dec10a70>
# M. Jean-FÃ©lix Acquaviva
# <Element p at 0x7fe5dec10b90>
# Article 8, alinÃ©a 6
# <Element p at 0x7fe5dec10cb0>
# M. Jean-FÃ©lix Acquaviva
# <Element p at 0x7fe5dec10950>
# Article 8, alinÃ©a 6
# <Element p at 0x7fe5dec08ef0>
# M. Fabien Roussel
# <Element p at 0x7fe5dec08e30>
# Article 8
# <Element p at 0x7fe5dec08590>
# M. Mohamed Laqhila
# <Element p at 0x7fe5dec084d0>
# Article 8, alinÃ©a 7
# <Element p at 0x7fe5dec08890>
# M. Patrick Hetzel
# <Element p at 0x7fe5dec08f50>
# Article 8, alinÃ©a 17
# <Element p at 0x7fe5dec08410>
# M. Ãric Woerth
# <Element p at 0x7fe5dec08e90>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5dec08a70>
# Mme ValÃ©rie Rabault
# <Element p at 0x7fe5dec08710>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5dec08950>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08fb0>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5dec08530>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5dec082f0>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5dec085f0>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec083b0>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5df1aed10>
# M. Ãric Coquerel
# <Element p at 0x7fe5df1aed70>
# Article 8, alinÃ©a 19
# <Element p at 0x7fe5df1ae6b0>
# Mme Sabine Rubin
# <Element p at 0x7fe5df160a70>
# Article 8, alinÃ©a 28
# <Element p at 0x7fe5df1602f0>
# M. Marc Le Fur
# <Element p at 0x7fe5df160470>
# Article 8, alinÃ©a 28
# <Element p at 0x7fe5df160230>
# Mme ValÃ©rie Rabault
# <Element p at 0x7fe5df160b30>
# Article 8, alinÃ©a 28
# <Element p at 0x7fe5df160590>
# M. Fabien Roussel
# <Element p at 0x7fe5df160830>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160770>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167350>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df167e30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167fb0>
# M. Bertrand Pancher
# <Element p at 0x7fe5df167cb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167710>
# M. Fabrice Brun
# <Element p at 0x7fe5df1675f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167650>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5df167050>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5df167f50>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=25
# <Element p at 0x7fe5debdba70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd050>
# M. Ãric Coquerel
# <Element p at 0x7fe5debfd590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdf50>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5debfda10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd830>
# M. Fabien Roussel
# <Element p at 0x7fe5debfd8f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd470>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5debfddd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdd70>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5dec10fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10770>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec10c50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec101d0>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec10710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10b30>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5dec10e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10650>
# M. Daniel Labaronne
# <Element p at 0x7fe5dec10bf0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10a70>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec107d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10b90>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec10cb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10950>
# M. Daniel Labaronne
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08e30>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec084d0>
# M. Jean-Michel Jacques
# <Element p at 0x7fe5dec08890>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08f50>
# M. Thomas Rudigoz
# <Element p at 0x7fe5dec08410>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08e90>
# M. Daniel Labaronne
# <Element p at 0x7fe5dec08a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08710>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08fb0>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec08530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec082f0>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5dec085f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec083b0>
# M. StÃ©phane Peu
# <Element p at 0x7fe5df1aed10>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5df1aed70>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=26
# <Element p at 0x7fe5debdba70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160530>
# M. AurÃ©lien TachÃ©
# <Element p at 0x7fe5df160230>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1606b0>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5df1602f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160770>
# M. Jean-Luc Lagleize
# <Element p at 0x7fe5df160830>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160a70>
# M. Fabrice Brun
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160590>
# M. Patrick Hetzel
# <Element p at 0x7fe5df160b30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167cb0>
# M. Patrice Anato
# <Element p at 0x7fe5df167350>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167470>
# Mme Lise Magnier
# <Element p at 0x7fe5df1675f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167650>
# M. Robin Reda
# <Element p at 0x7fe5df167e30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167710>
# M. Mohamed Laqhila
# <Element p at 0x7fe5df167050>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167fb0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df167f50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167e90>
# M. Marc Le Fur
# <Element p at 0x7fe5debfd050>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd590>
# M. Dino Cinieri
# <Element p at 0x7fe5debfdf50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfda10>
# M. Fabrice Brun
# <Element p at 0x7fe5debfd830>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd8f0>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5debfd470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfddd0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debfdd70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10fb0>
# M. Daniel Labaronne
# <Element p at 0x7fe5dec10770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10c50>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec101d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10710>
# M. Patrick Hetzel
# <Element p at 0x7fe5dec10b30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10e90>
# M. Patrice Anato
# <Element p at 0x7fe5dec10650>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10bf0>
# Mme Lise Magnier
# <Element p at 0x7fe5dec10a70>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec107d0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=27
# <Element p at 0x7fe5dec08410>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08a70>
# M. Robin Reda
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec085f0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec083b0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08530>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08590>
# M. Fabrice Brun
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1aed70>
# M. Patrick Hetzel
# <Element p at 0x7fe5df1aed10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1ae6b0>
# M. Patrice Anato
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160230>
# Mme Lise Magnier
# <Element p at 0x7fe5df1606b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1602f0>
# M. Vincent Rolland
# <Element p at 0x7fe5df160770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160830>
# M. Robin Reda
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160470>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5df160590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160b30>
# M. Charles de Courson
# <Element p at 0x7fe5df167cb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167350>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df167470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1675f0>
# Mme Lise Magnier
# <Element p at 0x7fe5df167650>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167e30>
# M. Dino Cinieri
# <Element p at 0x7fe5df167710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167050>
# M. Marc Le Fur
# <Element p at 0x7fe5df167fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167f50>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df167e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd050>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5debfd590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdf50>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5debfda10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd830>
# M. Dino Cinieri
# <Element p at 0x7fe5debfd8f0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfd470>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=28
# <Element p at 0x7fe5dec10a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10b90>
# M. Marc Le Fur
# <Element p at 0x7fe5dec10e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10710>
# M. FranÃ§ois Jolivet
# <Element p at 0x7fe5dec101d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08e90>
# M. Charles de Courson
# <Element p at 0x7fe5dec08410>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08a70>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec085f0>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5dec08fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec083b0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08530>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08590>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1aed70>
# Mme ValÃ©rie Bazin-Malgras
# <Element p at 0x7fe5df1aed10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1ae6b0>
# M. Marc Le Fur
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160230>
# M. Fabrice Brun
# <Element p at 0x7fe5df1606b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1602f0>
# M. Dino Cinieri
# <Element p at 0x7fe5df160770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160830>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160470>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5df160590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160b30>
# Mme Brigitte Kuster
# <Element p at 0x7fe5df167cb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167350>
# M. Fabien Di Filippo
# <Element p at 0x7fe5df167470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1675f0>
# M. Ãric Woerth
# <Element p at 0x7fe5df167650>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167e30>
# M. Fabrice Brun
# <Element p at 0x7fe5df167710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167050>
# M. Arnaud Viala
# <Element p at 0x7fe5df167fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167f50>
# M. Charles de Courson
# <Element p at 0x7fe5df167e90>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfddd0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=29
# <Element p at 0x7fe5debf3ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3e90>
# M. Bertrand Pancher
# <Element p at 0x7fe5debf3fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3dd0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec5acb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5aa70>
# M. Fabrice Brun
# <Element p at 0x7fe5dec5a770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5afb0>
# M. Ãric Woerth
# <Element p at 0x7fe5dec5a8f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5a9b0>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5dec5ab30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1616b0>
# Mme Lise Magnier
# <Element p at 0x7fe5debfd830>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd8f0>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5debfda10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd050>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debfd590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10cb0>
# M. Vincent Descoeur
# <Element p at 0x7fe5dec10d10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10ef0>
# Mme Sylvia Pinel
# <Element p at 0x7fe5dec10bf0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10a70>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5dec10b90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10e90>
# M. Arnaud Viala
# <Element p at 0x7fe5dec10710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec101d0>
# M. Julien Aubert
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08410>
# Mme Emmanuelle Anthoine
# <Element p at 0x7fe5dec08a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08950>
# Mme ValÃ©rie Bazin-Malgras
# <Element p at 0x7fe5dec085f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08fb0>
# Mme Ãmilie Bonnivard
# <Element p at 0x7fe5dec083b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec084d0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5dec08530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08ef0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec082f0>
# Mme Jeanine DubiÃ©
# <Element p at 0x7fe5df1aed70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1aed10>
# Mme Lise Magnier
# <Element p at 0x7fe5df1ae6b0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5df160710>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=30
# <Element p at 0x7fe5df160230>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160710>
# Mme Danielle Brulebois
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160470>
# M. Dino Cinieri
# <Element p at 0x7fe5df160770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160830>
# M. Jacques Cattin
# <Element p at 0x7fe5df1602f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160b30>
# M. Benoit Simian
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160590>
# M. Bertrand Pancher
# <Element p at 0x7fe5df1606b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167cb0>
# M. Dino Cinieri
# <Element p at 0x7fe5df167710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167fb0>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5df167050>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167e90>
# M. Marc Le Fur
# <Element p at 0x7fe5df167350>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167650>
# M. Laurent Saint-Martin
# <Element p at 0x7fe5df167470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167f50>
# Mme Sabine Rubin
# <Element p at 0x7fe5df167e30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1675f0>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5debf3bf0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3ef0>
# M. Charles de Courson
# <Element p at 0x7fe5debf3e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3fb0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debf3dd0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5acb0>
# M. Mohamed Laqhila
# <Element p at 0x7fe5dec5aa70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5a770>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5dec5afb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5a8f0>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5dec5a9b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5ab30>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5df1616b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd830>
# M. Mohamed Laqhila
# <Element p at 0x7fe5debfd8f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfda10>
# M. Marc Le Fur
# <Element p at 0x7fe5debfd050>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd590>
# M. Dino Cinieri
# <Element p at 0x7fe5dec10cb0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec10d10>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=31
# <Element p at 0x7fe5dec083b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08ef0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec085f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec082f0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08590>
# M. Dino Cinieri
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1aed10>
# M. Dino Cinieri
# <Element p at 0x7fe5df1aed70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1ae6b0>
# M. Dino Cinieri
# <Element p at 0x7fe5df1608f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160710>
# M. Marc Le Fur
# <Element p at 0x7fe5df160230>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160530>
# M. Marc Le Fur
# <Element p at 0x7fe5df160470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160770>
# M. Dino Cinieri
# <Element p at 0x7fe5df160830>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1602f0>
# M. Fabrice Brun
# <Element p at 0x7fe5df160b30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160a70>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df160590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1606b0>
# M. Dino Cinieri
# <Element p at 0x7fe5df167cb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167710>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df167fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167050>
# M. Julien Dive
# <Element p at 0x7fe5df167e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167350>
# M. Dino Cinieri
# <Element p at 0x7fe5df167650>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167470>
# M. Dino Cinieri
# <Element p at 0x7fe5df167f50>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167e30>
# M. Marc Le Fur
# <Element p at 0x7fe5df1675f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3bf0>
# M. Marc Le Fur
# <Element p at 0x7fe5debf3ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3e90>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5debf3fb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debf3dd0>
# Mme Emmanuelle Anthoine
# <Element p at 0x7fe5dec5acb0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5aa70>
# Mme ValÃ©rie Bazin-Malgras
# <Element p at 0x7fe5dec5a770>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec5afb0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=32
# <Element p at 0x7fe5dec10bf0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10b90>
# Mme Ãmilie Bonnivard
# <Element p at 0x7fe5dec10a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec101d0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec10d10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08fb0>
# M. Dino Cinieri
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec083b0>
# M. Charles de Courson
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec085f0>
# Mme Josiane Corneloup
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08e90>
# M. Julien Aubert
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec084d0>
# M. Jacques Cattin
# <Element p at 0x7fe5df1aed10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1aed70>
# M. Arnaud Viala
# <Element p at 0x7fe5df1ae6b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1608f0>
# M. Benoit Simian
# <Element p at 0x7fe5df160710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160230>
# M. Marc Le Fur
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160470>
# M. Dino Cinieri
# <Element p at 0x7fe5df160770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160830>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df1602f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160b30>
# M. Charles de Courson
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df160590>
# M. Fabien Roussel
# <Element p at 0x7fe5df1606b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167cb0>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5df167710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167fb0>
# M. Bertrand Pancher
# <Element p at 0x7fe5df167050>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167e90>
# Mme Patricia Lemoine
# <Element p at 0x7fe5df167350>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167650>
# Mme Patricia Lemoine
# <Element p at 0x7fe5df167470>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df167f50>
# M. Vincent Ledoux
# <Element p at 0x7fe5df167e30>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5df1675f0>
# M. Jean-Paul Mattei
# <Element p at 0x7fe5debf3bf0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3ef0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=33
# <Element p at 0x7fe5dec4a770>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec4a5f0>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5dec7f9b0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdb90>
# Mme Lise Magnier
# <Element p at 0x7fe5debfde90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfdad0>
# Mme Sylvia Pinel
# <Element p at 0x7fe5debfdbf0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5debfd9b0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debdb590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec5a9b0>
# Mme FrÃ©dÃ©rique Lardet
# <Element p at 0x7fe5dec10710>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10bf0>
# Mme Lise Magnier
# <Element p at 0x7fe5dec10e90>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec10b90>
# Mme FrÃ©dÃ©rique Lardet
# <Element p at 0x7fe5dec10a70>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec101d0>
# Mme Sylvia Pinel
# <Element p at 0x7fe5dec10d10>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08fb0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec083b0>
# Mme GeneviÃ¨ve Levy
# <Element p at 0x7fe5dec08ef0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec085f0>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec08e90>
# Mme Lise Magnier
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 8
# <Element p at 0x7fe5dec084d0>
# M. Jean-NoÃ«l Barrot
# <Element p at 0x7fe5df1aed10>
# Article 9
# <Element p at 0x7fe5df1aed70>
# M. Christophe Naegelen
# <Element p at 0x7fe5df1ae6b0>
# Article 9, alinÃ©a 38
# <Element p at 0x7fe5df1608f0>
# M. FranÃ§ois Ruffin
# <Element p at 0x7fe5df160710>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160230>
# M. Fabrice Brun
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160470>
# M. Marc Le Fur
# <Element p at 0x7fe5df160770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160830>
# M. Dino Cinieri
# <Element p at 0x7fe5df1602f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160b30>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160590>
# M. Vincent Descoeur
# <Element p at 0x7fe5df1606b0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5df167cb0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=34
# <Element p at 0x7fe5df167350>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167cb0>
# Mme Sylvia Pinel
# <Element p at 0x7fe5df167e90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df1675f0>
# Mme Marie-Christine Dalloz
# <Element p at 0x7fe5df167710>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167470>
# M. Dino Cinieri
# <Element p at 0x7fe5df167050>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167f50>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5df167e30>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167fb0>
# M. StÃ©phane Peu
# <Element p at 0x7fe5debf3b90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3e90>
# M. AurÃ©lien TachÃ©
# <Element p at 0x7fe5debf3b30>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3770>
# Mme Josiane Corneloup
# <Element p at 0x7fe5debf39b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3dd0>
# M. Patrick Hetzel
# <Element p at 0x7fe5debf3bf0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3ef0>
# M. Patrice Anato
# <Element p at 0x7fe5debf3fb0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3f50>
# M. Vincent Rolland
# <Element p at 0x7fe5debf3830>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3ad0>
# Mme Lise Magnier
# <Element p at 0x7fe5dec4a710>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec4a770>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec4a5f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec7f9b0>
# M. Robin Reda
# <Element p at 0x7fe5debfdb90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debfde90>
# Mme Brigitte Kuster
# <Element p at 0x7fe5debfdad0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debfdbf0>
# M. Fabrice Brun
# <Element p at 0x7fe5debfd9b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debdb590>
# M. Guillaume Chiche
# <Element p at 0x7fe5dec5a9b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec10710>
# M. Xavier Paluszkiewicz
# <Element p at 0x7fe5dec10bf0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec10e90>
# Mme Aina Kuric
# <Element p at 0x7fe5dec10b90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec10a70>
# M. Julien Aubert
# <Element p at 0x7fe5dec101d0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec10d10>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5dec08fb0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec08950>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=35
# <Element p at 0x7fe5df160230>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160470>
# M. Dino Cinieri
# <Element p at 0x7fe5df1602f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160710>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5df160770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160830>
# M. Marc Le Fur
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df1606b0>
# M. Fabrice Brun
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df1608f0>
# M. Marc Le Fur
# <Element p at 0x7fe5df160b30>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160590>
# M. Fabrice Brun
# <Element p at 0x7fe5df167650>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167350>
# M. Dino Cinieri
# <Element p at 0x7fe5df167cb0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167e90>
# M. Fabrice Brun
# <Element p at 0x7fe5df1675f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167710>
# M. Fabrice Brun
# <Element p at 0x7fe5df167470>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167050>
# M. Fabrice Brun
# <Element p at 0x7fe5df167f50>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167e30>
# M. Fabrice Brun
# <Element p at 0x7fe5df167fb0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3b90>
# M. Matthieu Orphelin
# <Element p at 0x7fe5debf3e90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3b30>
# M. Pierre-Yves Bournazel
# <Element p at 0x7fe5debf3770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf39b0>
# M. Fabrice Brun
# <Element p at 0x7fe5debf3dd0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3bf0>
# M. Matthieu Orphelin
# <Element p at 0x7fe5debf3ef0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3fb0>
# M. Julien Aubert
# <Element p at 0x7fe5debf3f50>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3830>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5debf3ad0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec4a710>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5dec4a770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec4a5f0>
# M. Pascal Brindeau
# <Element p at 0x7fe5dec7f9b0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debfdb90>
# M. Vincent Rolland
# <Element p at 0x7fe5debfde90>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfdad0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=36
# <Element p at 0x7fe5dec101d0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08fb0>
# M. Marc Le Fur
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec083b0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08590>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec082f0>
# Mme Ãmilie Bonnivard
# <Element p at 0x7fe5dec08950>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec08ef0>
# M. Denis MassÃ©glia
# <Element p at 0x7fe5dec084d0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec085f0>
# M. Marc Le Fur
# <Element p at 0x7fe5df160230>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160470>
# Mme Sabine Rubin
# <Element p at 0x7fe5df1602f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160710>
# M. Jean-Marc Zulesi, rapporteur de la commission du dÃ©veloppement durable et de l'amÃ©nagement du territoire
# <Element p at 0x7fe5df160770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160830>
# M. Fabien Roussel
# <Element p at 0x7fe5df160a70>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df1606b0>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5df160530>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df1608f0>
# Mme Ãmilie Cariou
# <Element p at 0x7fe5df160b30>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df160590>
# M. Matthieu Orphelin
# <Element p at 0x7fe5df167650>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167350>
# M. Michel Castellani
# <Element p at 0x7fe5df167cb0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167e90>
# M. Jean-Marc Zulesi, rapporteur de la commission du dÃ©veloppement durable et de l'amÃ©nagement du territoire
# <Element p at 0x7fe5df1675f0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167710>
# Mme Laurianne Rossi
# <Element p at 0x7fe5df167470>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167050>
# M. Marc Le Fur
# <Element p at 0x7fe5df167f50>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5df167e30>
# M. Fabrice Brun
# <Element p at 0x7fe5df167fb0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3b90>
# M. Ãric Coquerel
# <Element p at 0x7fe5debf3e90>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3b30>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5debf3770>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf39b0>
# M. Fabrice Brun
# <Element p at 0x7fe5debf3dd0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debf3bf0>
# Mme Ãmilie Bonnivard
# <Element p at 0x7fe5debf3ef0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debf3fb0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=37
# <Element p at 0x7fe5dec5abf0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5a830>
# M. Fabien Di Filippo
# <Element p at 0x7fe5dec5aad0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5aa10>
# M. Julien Dive
# <Element p at 0x7fe5dec5ad70>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec5ad10>
# M. Dino Cinieri
# <Element p at 0x7fe5dec5a950>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5debdb4d0>
# Mme Pascale Fontenel-Personne
# <Element p at 0x7fe5dec4a7d0>
# AprÃ¨s l'Article 9
# <Element p at 0x7fe5dec44ef0>
# Mme Ãmilie Bonnivard
# ...
# <Element p at 0x7fe5dec5afb0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec4a710>
# M. Charles de Courson
# <Element p at 0x7fe5dec4a770>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec4a5f0>
# Mme ValÃ©rie Bazin-Malgras
# <Element p at 0x7fe5dec16170>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec160b0>
# Mme Emmanuelle Anthoine
# <Element p at 0x7fe5dec7f9b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec7f350>
# M. StÃ©phane TestÃ©
# <Element p at 0x7fe5dec859b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec28950>
# Mme Monica Michel
# <Element p at 0x7fe5dec08410>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec086b0>
# Mme Marie Tamarelle-Verhaeghe
# <Element p at 0x7fe5dec08590>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec082f0>
# M. Jean-Michel Jacques
# <Element p at 0x7fe5dec08890>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec08530>
# M. Gabriel Serville
# <Element p at 0x7fe5dec08e90>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec084d0>
# Mme SÃ©verine Gipson
# <Element p at 0x7fe5dec085f0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfd050>
# Mme Danielle Brulebois
# <Element p at 0x7fe5debfdd70>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfd470>
# M. Patrick Vignal
# <Element p at 0x7fe5debfdad0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfdbf0>
# M. Patrice Anato
# <Element p at 0x7fe5debfd590>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfd830>
# M. Olivier Becht
# <Element p at 0x7fe5debfddd0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfd650>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=70
# <Element p at 0x7fe5dec5a770>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5ab30>
# Mme Isabelle Valentin
# <Element p at 0x7fe5dec5acb0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5ac50>
# M. RÃ©mi Delatte
# <Element p at 0x7fe5dec5a8f0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5aa70>
# M. StÃ©phane Viry
# <Element p at 0x7fe5dec5afb0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec4a710>
# M. Christophe Naegelen
# <Element p at 0x7fe5dec4a770>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec4a5f0>
# M. Bertrand Bouyx
# <Element p at 0x7fe5dec16170>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec160b0>
# Mme FrÃ©dÃ©rique Tuffnell
# <Element p at 0x7fe5dec7f9b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec7f350>
# Mme Aude Bono-Vandorme
# <Element p at 0x7fe5dec859b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec28950>
# M. Jean-Hugues Ratenon
# <Element p at 0x7fe5dec08410>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec086b0>
# M. Thierry Michels
# <Element p at 0x7fe5dec08590>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec082f0>
# M. Vincent Rolland
# <Element p at 0x7fe5dec08890>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec08530>
# M. Emmanuel Maquet
# <Element p at 0x7fe5dec08e90>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec084d0>
# M. Robin Reda
# <Element p at 0x7fe5dec085f0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfd650>
# Mme Stella Dupont
# <Element p at 0x7fe5debfd050>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfdd70>
# M. Jean-Yves Bony
# <Element p at 0x7fe5debfd470>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfdad0>
# M. FranÃ§ois Jolivet
# <Element p at 0x7fe5debfdbf0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfd590>
# Mme Huguette Tiegna
# <Element p at 0x7fe5debfd830>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfddd0>
# M. Philippe Meyer
# <Element p at 0x7fe5dec10d10>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10b90>
# Mme FranÃ§oise Dumas
# <Element p at 0x7fe5dec10770>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10ad0>
# M. Julien Aubert
# <Element p at 0x7fe5dec10ef0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec10950>
# M. Denis Sommer
# <Element p at 0x7fe5dec10830>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec10e90>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=71
# <Element p at 0x7fe5dec5ad10>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a950>
# Mme Sabine Thillaye
# <Element p at 0x7fe5dec5ad70>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5abf0>
# M. Jean-Paul DufrÃ¨gne
# <Element p at 0x7fe5dec5aa10>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec5a830>
# M. FranÃ§ois Pupponi
# <Element p at 0x7fe5dec44ef0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5df1603b0>
# M. Patrick Mignola
# <Element p at 0x7fe5dec4a7d0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec4a770>
# Mme ValÃ©rie Rabault
# <Element p at 0x7fe5dec4a710>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec4a5f0>
# M. Jean-Pierre Door
# <Element p at 0x7fe5dec16170>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec160b0>
# M. Florent BoudiÃ©
# <Element p at 0x7fe5dec7f9b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec7f350>
# Mme Annie Chapelier
# <Element p at 0x7fe5dec859b0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec28950>
# M. Arnaud Viala
# <Element p at 0x7fe5dec08f50>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec08e30>
# M. Vincent Descoeur
# <Element p at 0x7fe5dec08410>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec086b0>
# M. Christophe Blanchet
# <Element p at 0x7fe5dec08590>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec082f0>
# M. Jean-Pierre Cubertafon
# <Element p at 0x7fe5dec08890>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec08530>
# Mme Aude Luquet
# <Element p at 0x7fe5dec08e90>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5dec084d0>
# M. Arnaud Viala
# <Element p at 0x7fe5dec085f0>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfdd10>
# Mme Anne-Laure Cattelot
# <Element p at 0x7fe5debfde90>
# Article 24, alinÃ©a 11
# <Element p at 0x7fe5debfd2f0>
# M. Xavier Roseren
# <Element p at 0x7fe5debfd9b0>
# Article 24, alinÃ©a 25
# <Element p at 0x7fe5debfda70>
# M. Ãric Woerth
# <Element p at 0x7fe5debfd7d0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debfd650>
# M. Bertrand Pancher
# <Element p at 0x7fe5debfd050>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debfdd70>
# M. Bertrand Pancher
# <Element p at 0x7fe5debfd470>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5debfdad0>
# M. Jean-Paul Lecoq
# <Element p at 0x7fe5debfdbf0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5debfd590>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=72
# <Element p at 0x7fe5dec10b90>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10fb0>
# M. Bertrand Pancher
# <Element p at 0x7fe5dec10a70>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10b30>
# M. Bertrand Pancher
# <Element p at 0x7fe5dec10c50>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10bf0>
# Mme Jennifer De Temmerman
# <Element p at 0x7fe5dec10f50>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10650>
# M. Hubert Julien-LaferriÃ¨re
# <Element p at 0x7fe5dec10590>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10e90>
# M. Fabrice Brun
# <Element p at 0x7fe5dec10ef0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec107d0>
# M. Fabrice Brun
# <Element p at 0x7fe5dec10770>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10950>
# M. Fabrice Brun
# <Element p at 0x7fe5dec10d10>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10cb0>
# Mme Jennifer De Temmerman
# <Element p at 0x7fe5dec101d0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10830>
# Mme Jennifer De Temmerman
# <Element p at 0x7fe5dec104d0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec10ad0>
# Mme Jennifer De Temmerman
# <Element p at 0x7fe5dec5ad10>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec5a950>
# Mme Anne-Laure Cattelot
# <Element p at 0x7fe5dec5ad70>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec5abf0>
# M. Xavier Roseren
# <Element p at 0x7fe5dec5aa10>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec5a830>
# M. Jean-Paul Lecoq
# <Element p at 0x7fe5dec44ef0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5df1603b0>
# M. Hubert Julien-LaferriÃ¨re
# <Element p at 0x7fe5dec4a7d0>
# Article 24, alinÃ©a 26
# <Element p at 0x7fe5dec4a770>
# M. Hubert Julien-LaferriÃ¨re
# <Element p at 0x7fe5dec4a710>
# Article 24, alinÃ©a 56
# <Element p at 0x7fe5dec4a5f0>
# Mme VÃ©ronique Louwagie
# <Element p at 0x7fe5dec16170>
# Article 24
# <Element p at 0x7fe5dec160b0>
# M. Charles de Courson
# <Element p at 0x7fe5dec7f9b0>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5dec7f350>
# M. Michel Lauzzana
# <Element p at 0x7fe5dec859b0>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5dec28950>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08f50>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5dec08e30>
# M. Fabrice Brun
# <Element p at 0x7fe5dec08410>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec086b0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=73
# <Element p at 0x7fe5debfdad0>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debfd650>
# M. Fabrice Brun
# <Element p at 0x7fe5debfd590>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debfde90>
# Mme Anne-Laure Cattelot
# <Element p at 0x7fe5debfddd0>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debfda70>
# Mme Anne-Laure Cattelot
# <Element p at 0x7fe5debfd830>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debfdd70>
# M. Xavier Roseren
# <Element p at 0x7fe5debfdbf0>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debfd2f0>
# M. Xavier Roseren
# <Element p at 0x7fe5debfd050>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debfd9b0>
# M. Philippe HuppÃ©
# <Element p at 0x7fe5debfdd10>
# AprÃ¨s l'Article 24
# <Element p at 0x7fe5debfd7d0>
# M. Denis MassÃ©glia
# <Element p at 0x7fe5dec10b90>
# Article 25
# <Element p at 0x7fe5dec10fb0>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec10a70>
# Article 25
# <Element p at 0x7fe5dec10b30>
# M. Ãric Woerth
# <Element p at 0x7fe5dec10c50>
# Article 27
# <Element p at 0x7fe5dec10bf0>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec10f50>
# Article 27, alinÃ©a 2
# <Element p at 0x7fe5dec10650>
# Mme FrÃ©dÃ©rique Dumas
# <Element p at 0x7fe5dec10590>
# Article 28
# <Element p at 0x7fe5dec10e90>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec10ef0>
# AprÃ¨s l'Article 28
# <Element p at 0x7fe5dec107d0>
# M. Michel Zumkeller
# <Element p at 0x7fe5dec10770>
# Article 30
# <Element p at 0x7fe5dec10950>
# M. Ãric Coquerel
# <Element p at 0x7fe5dec10d10>
# AprÃ¨s l'Article 30
# <Element p at 0x7fe5dec10cb0>
# M. SÃ©bastien Nadot
# <Element p at 0x7fe5dec101d0>
# AprÃ¨s l'Article 30
# <Element p at 0x7fe5dec10830>
# M. Patrice Anato
# <Element p at 0x7fe5dec104d0>
# AprÃ¨s l'Article 30
# <Element p at 0x7fe5dec10ad0>
# M. Philippe HuppÃ©
# <Element p at 0x7fe5dec5ad10>
# Article 31
# <Element p at 0x7fe5dec5a950>
# M. Michel Zumkeller
# <Element p at 0x7fe5dec5ad70>
# Article 31
# <Element p at 0x7fe5dec5abf0>
# M. Julien Aubert
# <Element p at 0x7fe5dec5aa10>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec5a830>
# M. RaphaÃ«l GÃ©rard
# <Element p at 0x7fe5dec44ef0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5df1603b0>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits
#
# https://www.assemblee-nationale.fr/dyn/15/amendements?dossier_legislatif=DLR5L15N40245&examen=EXANR5L15PO59048B3360P1D1&page=74
# <Element p at 0x7fe5dec16170>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec7f9b0>
# Mme Lise Magnier
# <Element p at 0x7fe5dec7f350>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec08590>
# M. Charles de Courson
# <Element p at 0x7fe5dec082f0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec08f50>
# Mme Christine Pires Beaune
# <Element p at 0x7fe5dec08530>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec08890>
# M. Mohamed Laqhila
# <Element p at 0x7fe5dec086b0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec084d0>
# Mme Sabine Rubin
# <Element p at 0x7fe5dec08e90>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec08410>
# Mme Marie-Pierre Rixain
# <Element p at 0x7fe5dec085f0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec08e30>
# M. Florent BoudiÃ©
# <Element p at 0x7fe5debfd470>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debfdad0>
# Mme Lise Magnier
# <Element p at 0x7fe5debfd650>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debfd590>
# M. Mohamed Laqhila
# <Element p at 0x7fe5debfde90>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debfddd0>
# Mme Lise Magnier
# <Element p at 0x7fe5debfda70>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debfd830>
# M. Fabien Di Filippo
# <Element p at 0x7fe5debfdd70>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debfdbf0>
# M. Julien Aubert
# <Element p at 0x7fe5debfd2f0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debfd050>
# M. Julien Aubert
# <Element p at 0x7fe5debfd9b0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5debfdd10>
# M. Jean-Philippe Nilor
# <Element p at 0x7fe5debfd7d0>
# AprÃ¨s l'Article 31
# <Element p at 0x7fe5dec10b90>
# M. Jean-Philippe Nilor
# <Element p at 0x7fe5dec10fb0>
#
#                                     Inscrivez-vous Ã  notre lettre Une semaine Ã  l'AssemblÃ©e et recevez tous
#                                     les vendredis dans votre messagerie les temps forts de l'actualitÃ© de la semaine Ã  venir !
#
# <Element p at 0x7fe5dec10a70>
#
#                                     Votre adresse de messagerie est uniquement utilisÃ©e pour vous envoyer les lettres de l'AssemblÃ©e nationale.
#                                     Vous pouvez Ã  tout moment utiliser le lien de dÃ©sabonnement intÃ©grÃ© dans la lettre.
#                                     En savoir plus sur la gestion de vos donnÃ©es et de vos droits

# %% [markdown]
# ## The new code
#
# The first line of new code is this:
#
# `df = pd.DataFrame(columns=["title"])`
#
# We are creating a new variable here, called `df`, and assigning to it the results of using a function: `pd.DataFrame()` (the `pandas` function `DataFrame`).
#
# That takes an ingredient which specifies the columns as being a list (note the square brackets) of one string: `"title"`.
#
# The second line of new code is this:
#
# ```
# df = df.append({
#       "title" : title
#       }, ignore_index=True)
# ```
#
# This takes the `df` variable and updates it.
#
# On the right of the equals sign is `df.append()` - this means it is using a function called `append` to append (add) new data to the `df` variable it's attached to.
#
# The `append` function [can include various ingredients](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.append.html): firstly the data that you want to append to the dataframe; but also settings, such as whether you want something called `ignore_index` to be `True` or `False`. Setting this to `True` just avoids problems when your data isn't unique.
#
# What about the data that you are appending? Well, this has to be in the form of a **dictionary**. A dictionary is like a list, but with two key differences: firstly that it uses curly brackets instead of square ones: `{}`, and secondly it's a list of *pairs*: a 'key', and a 'value', separated by a colon.
#
# Here's the dictionary in our code:
#
# `{"title" : title}`
#
# The first part, `"title"` is the **key**. This matches the column heading in the empty data frame. Note that it's a **string**: a label, basically.
#
# The second part, `title`, is the **value**. This isn't in quotes so it's not a string - it's a variable. A few lines earlier we created this variable with `title = i.text_content()`
#
# So having extracted that information and stored it in `title`, the line of code is storing it in a dataframe with the label (key) "title":
#
# ```
# df = df.append({
#       "title" : title
#       }, ignore_index=True)
# ```
#
# We can print the dataframe to see what's in there:

# %%
#Once the loop has finished we can take a look at the data
print(df)
# Out:
#                                                     Nom
# 0                             Article UNIQUE, alinÃ©a 2
# 1                                 M. Charles de Courson
# 2                             Article UNIQUE, alinÃ©a 2
# 3                                  Mme ValÃ©rie Rabault
# 4                             Article UNIQUE, alinÃ©a 2
# ...                                                 ...
# 3093                             M. Jean-Philippe Nilor
# 3094                                AprÃ¨s l'Article 31
# 3095                             M. Jean-Philippe Nilor
# 3096  \n                                    Inscrive...
# 3097  \n                                    Votre ad...
#
# [3098 rows x 1 columns]

# %% [markdown]
# ## Exporting the data
#
# The `pandas` library has another function for exporting data: `to_csv()`.
#
# It needs to be attached to the name of the dataframe variable with a period, then, in the brackets, you specify the name of the file you want to export it as. Make sure this ends in '.csv' so it can be used in a spreadsheet.

# %%
#And we can export it
df.to_csv("DeputesPLFPage1à74.csv")

# %% [markdown]
# ## Downloading the data
#
# Once exported, it should appear in the file explorer in Google Colab on the left hand side. Click on the folder icon to open this up and you should see the file you just created (there's a refresh button above if you can't).
#
# Hover over the file name to see three dots, then click on those to select **Download** and download to your computer.

# %% [markdown]
# ## How to adapt it
#
# You can use most of this code without having to change it. All you *need* to change is the lines specifying the base URL, and the list of words to add to it.
#
# And this line, which specifies what you want to scrape from that page:
#
# `titles = root.cssselect('h2')`
#
# If you're scraping one type of information from one page, that will be enough.
#
# For the CSS selector you will need to identify the HTML in the page you are scraping, and the combination of tags that is being used.
#
# Some [reading around CSS selectors](https://www.w3schools.com/cssref/css_selectors.asp) will help you here, but a couple of useful things to know include:
#
# * A period `.` means `class="`
# * A hash `#` means `id="`
#
# So `'div.title a'` means `<div class="title"><a ...>` - or, in other words, anything on the page inside an `<a>` tag (a link) within a `<div class="title">` tag.
#
# The words used for variables (like "baseurl" and "titles" above) may not be relevant to what you are scraping - but that doesn't matter, because those words are arbitrary. If you do decide to change them, make sure you change them *throughout* the code, or it will create an error.

# %% [markdown]
# ## Generating URLs for a scraper to loop through
#
# Alternatively you might *generate* the URLs: for example, if they end in a number that goes up by 1 each time you can use `range` to generate that list of numbers and add them to the URL using `+`.
#
# However, you cannot mix numbers and strings, so you need to convert the numbers to a string as you do this. Here's an example:

# %%
#Create the basic URL that appears before the number
baseurl = "http://mypage.com?page="
#Create a list of numbers to put on the end
pagenums = range(1,11)
#Now generate the URLs by looping through the list and adding it to the URL
for i in pagenums:
  #Combine the two - 
  #this will generate an error because we are trying to combine a string and a number
  fullurl = baseurl+i
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-fe2fd370c033> in <module>()
#       6   #Combine the two -
#       7   #this will generate an error because we are trying to combine a string and a number
# ----> 8   fullurl = baseurl+i
#
# TypeError: must be str, not int

# %% [markdown]
# ## Tip: converting numbers into strings
#
# You can see the error `must be str, not int` - in other words the second part must be a string not an integer.
#
# To fix that you can use the `str()` function, which will convert a number into a string.

# %%
#Create the basic URL that appears before the number
baseurl = "http://mypage.com?page="
#Create a list of numbers to put on the end
pagenums = range(1,11)
#Now generate the URLs by looping through the list and adding it to the URL
for i in pagenums:
  #Convert i to a string
  i = str(i)
  #Combine the two
  fullurl = baseurl+i
  #print it
  print(fullurl)
# Out:
# http://mypage.com?page=1
# http://mypage.com?page=2
# http://mypage.com?page=3
# http://mypage.com?page=4
# http://mypage.com?page=5
# http://mypage.com?page=6
# http://mypage.com?page=7
# http://mypage.com?page=8
# http://mypage.com?page=9
# http://mypage.com?page=10
